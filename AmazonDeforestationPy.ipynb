# %%
import pandas as pd
import matplotlib.pyplot as plt
# Dependencies
import requests
from pprint import pprint
import numpy as np
import gmaps
import json
import os
from scipy.stats import linregress
from datetime import datetime
import time

# Google developer API key
#from config import g_key

# %%
deforest_df = pd.read_csv("csv_files/deforestation_by_brazil_state.csv")

deforest_df=deforest_df.rename(columns={"Years": "Year","ACRE": "AC_km2", "AMAPÁ":"AP_km2","AMAZONAS":"AM_km2","MARANHÃO":"MA_km2","MATO GROSSO":"MT_km2","PARÁ":"PA_km2", "RONDÔNIA":"RO_km2", "RORAIMA":"RR_km2","TOCANTINS":"TO_km2"})


deforest_df.set_index("Year", inplace =True)
deforest_df=deforest_df.drop(["RO_km2"],axis=1)
deforest_summed=deforest_df.cumsum()

deforest_summed.to_csv("csv_files/total_deforestation_data.csv")

deforest_df.to_csv("csv_files/clean_deforestation_data.csv")

# %%
deforest_df
# Out:
#       AC_km2  AP_km2  AM_km2  MA_km2  MT_km2  PA_km2  RR_km2  TO_km2  \
# Year
# 1988     620      60     151     245     514     699     290     165
# 1989     540     130     118     142     596     575     630     730
# 1990     550     250     520      11     402     489     150     580
# 1991     380     410     980     670     284     378     420     440
# 1992     400      36     799    1135    4674    3787     281     409
# 1993     482       0     370     372     622    4284     240     333
# 1994     482       0     370     372     622    4284     240     333
# 1995    1208       9    2114    1745   10391    7845     220     797
# 1996     433       0    1023    1061    6543    6135     214     320
# 1997     358      18     589     409    5271    4139     184     273
# 1998     536      30     670    1012    6466    5829     223     576
# 1999     441       0     720     123    6963    5111     220     216
# ...

# %%
#figure, axes =plt.subplots(1,2)
#deforest_df["MATO GROSSO"].plot(ax=axes[0])
#deforest_df["ACRE"].plot(ax=axes[1])
