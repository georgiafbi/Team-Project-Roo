# %%
import pandas as pd
import matplotlib.pyplot as plt
# Dependencies
import requests
from pprint import pprint
import numpy as np
import gmaps
import json
import os
from scipy.stats import linregress
from datetime import datetime
import time

# Google developer API key
#from config import g_key

# %%
deforest_df = pd.read_csv("csv_files/deforestation_by_brazil_state.csv")

deforest_df=deforest_df.rename(columns={"Acre": "AC", "AMAPÁ":"AP","AMAZONAS":"AM","MARANHÃO":"MA","MATO GROSSO":"MT","PARÁ":"PA", "RONDÔNIA":"RO", "RORAIMA":"RR","TOCANTINS":"TO"})


deforest_df.set_index("Years", inplace =True)

deforest_df.to_csv("csv_files/clean_defostation_data.csv")

deforest_df
# Out:
#        ACRE   AP    AM    MA     MT    PA    RO   RR   TO  Grand Total
# Years
# 1988    620   60   151   245    514   699   234  290  165         2978
# 1989    540  130   118   142    596   575   143  630  730         3604
# 1990    550  250   520    11    402   489   167  150  580         3119
# 1991    380  410   980   670    284   378   111  420  440         4073
# 1992    400   36   799  1135   4674  3787  2265  281  409        13786
# 1993    482    0   370   372    622  4284  2595  240  333         9298
# 1994    482    0   370   372    622  4284  2595  240  333         9298
# 1995   1208    9  2114  1745  10391  7845   473  220  797        24802
# 1996    433    0  1023  1061   6543  6135  2432  214  320        18161
# 1997    358   18   589   409   5271  4139  1986  184  273        13227
# 1998    536   30   670  1012   6466  5829  2041  223  576        17383
# 1999    441    0   720   123   6963  5111  2358  220  216        16152
# ...

# %%
#ax1=deforest_df.pivot(index="Years", values=['AP',"AM","MA","MT","PA","RO","RR","TO"])
#ax1.plot()

# %%
#figure, axes =plt.subplots(1,2)
#deforest_df["MATO GROSSO"].plot(ax=axes[0])
#deforest_df["ACRE"].plot(ax=axes[1])
